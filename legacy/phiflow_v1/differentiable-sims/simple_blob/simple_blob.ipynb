# %% [markdown]
# # Setting up the differentiable blob

# %%
from phi.tf.flow import *  # Causes deprecation warnings with TF 1.15
import pylab
session = Session(None)  # Used to run the TensorFlow graph

# %load_ext autoreload
# %autoreload 2
# Out:
# Could not load resample cuda libraries: CUDA binaries not found at /home/intergalactic-mammoth/anaconda3/envs/tf/lib/python3.7/site-packages/phi/tf/cuda/build/resample.so. Run "python setup.py cuda" to compile them
# WARNING:tensorflow:From /home/intergalactic-mammoth/anaconda3/envs/tf/lib/python3.7/site-packages/phi/tf/util.py:119: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /home/intergalactic-mammoth/anaconda3/envs/tf/lib/python3.7/site-packages/phi/tf/profiling.py:12: The name tf.RunOptions is deprecated. Please use tf.compat.v1.RunOptions instead.
#
# WARNING:tensorflow:From /home/intergalactic-mammoth/anaconda3/envs/tf/lib/python3.7/site-packages/phi/tf/profiling.py:13: The name tf.RunMetadata is deprecated. Please use tf.compat.v1.RunMetadata instead.
#
# WARNING:tensorflow:From /home/intergalactic-mammoth/anaconda3/envs/tf/lib/python3.7/site-packages/phi/tf/session.py:17: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/intergalactic-mammoth/anaconda3/envs/tf/lib/python3.7/site-packages/phi/tf/session.py:18: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
#Create 2 batch sim, target and source blob
#buoyancy is set to zero

world = World()
fluid = world.add(Fluid(Domain([32, 32], boundaries=CLOSED), buoyancy_factor=0.0, batch_size=2), physics=IncompressibleFlow())
world.add(Inflow(Sphere(center=[[16,14], [16, 18]], radius=3), rate=0.1));
fluid.velocity = variable(fluid.velocity)  # create TensorFlow variable
states = []
states.append(fluid.state)  # Remember the state at t=0 for later visualization
session.initialize_variables()
# Out:
# WARNING:tensorflow:From /home/intergalactic-mammoth/anaconda3/envs/tf/lib/python3.7/site-packages/phi/tf/session.py:29: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.

# %%
#See tensorflow variables
[print(grid.data) for grid in fluid.velocity.unstack()];
# Out:
# <tf.Variable 'Variable/data/0/data:0' shape=(2, 33, 32, 1) dtype=float32_ref>
# <tf.Variable 'Variable/data/1/data:0' shape=(2, 32, 33, 1) dtype=float32_ref>

# %%
for frame in range(10):
  print('Building graph for frame %d' % frame)
  world.step(dt=1.5)
  states.append(fluid.state)


print('Computing frames...')
pylab.imshow(np.concatenate(session.run(fluid.density).data[...,0], axis=1), origin='lower', cmap='magma')
# Out:
# Building graph for frame 0
# Building graph for frame 1
# Building graph for frame 2
# Building graph for frame 3
# Building graph for frame 4
# Building graph for frame 5
# Building graph for frame 6
# Building graph for frame 7
# Building graph for frame 8
# Building graph for frame 9
# Computing frames...

# %%
#Define loss function
#Want the densities of the right blob to match the ones of the left blob (target)

target = session.run(fluid.density).data[0,...]
loss = math.l2_loss(fluid.density.data[1:,...] - target)
optim = tf.train.AdamOptimizer(learning_rate=0.075).minimize(loss)
#optim = tf.train.AdadeltaOptimizer(learning_rate=5).minimize(loss)
session.initialize_variables()
print('Initial loss: %f' % session.run(loss))
# Out:
# WARNING:tensorflow:From /home/intergalactic-mammoth/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Initial loss: 39.989899

# %%
#Run optimization

for optim_step in range(300):
  print('Running optimization step %d. %s' % (optim_step, '' if optim_step else 'The first step sets up the adjoint graph.'))
  _, loss_value = session.run([optim, loss])
  print('Loss: %f' % loss_value)
# Out:
# Running optimization step 0. The first step sets up the adjoint graph.
# Loss: 39.989899
# Running optimization step 1.
# Loss: 21.964317
# Running optimization step 2.
# Loss: 11.670052
# Running optimization step 3.
# Loss: 8.298354
# Running optimization step 4.
# Loss: 8.882933
# Running optimization step 5.
# Loss: 10.526114
# Running optimization step 6.
# Loss: 11.645926
# Running optimization step 7.
# Loss: 12.205217
# Running optimization step 8.
# Loss: 12.362286
# Running optimization step 9.
# Loss: 12.249993
# Running optimization step 10.
# Loss: 11.963648
# Running optimization step 11.
# Loss: 11.495855
# Running optimization step 12.
# Loss: 10.837646
# Running optimization step 13.
# Loss: 10.096088
# Running optimization step 14.
# Loss: 9.473459
# Running optimization step 15.
# Loss: 9.092104
# Running optimization step 16.
# Loss: 8.841337
# Running optimization step 17.
# Loss: 8.543282
# Running optimization step 18.
# Loss: 8.181946
# Running optimization step 19.
# Loss: 7.899728
# Running optimization step 20.
# Loss: 7.846680
# Running optimization step 21.
# Loss: 7.890715
# Running optimization step 22.
# Loss: 7.896615
# Running optimization step 23.
# Loss: 7.808850
# Running optimization step 24.
# Loss: 7.660472
# Running optimization step 25.
# Loss: 7.491487
# Running optimization step 26.
# Loss: 7.317712
# Running optimization step 27.
# Loss: 7.208551
# Running optimization step 28.
# Loss: 7.197510
# Running optimization step 29.
# Loss: 7.177251
# Running optimization step 30.
# Loss: 7.125603
# Running optimization step 31.
# Loss: 7.075640
# Running optimization step 32.
# Loss: 7.047969
# Running optimization step 33.
# Loss: 6.995406
# Running optimization step 34.
# Loss: 6.889112
# Running optimization step 35.
# Loss: 6.751494
# Running optimization step 36.
# Loss: 6.637110
# Running optimization step 37.
# Loss: 6.571774
# Running optimization step 38.
# Loss: 6.547152
# Running optimization step 39.
# Loss: 6.526356
# Running optimization step 40.
# Loss: 6.521548
# Running optimization step 41.
# Loss: 6.497319
# Running optimization step 42.
# Loss: 6.422919
# Running optimization step 43.
# Loss: 6.333744
# Running optimization step 44.
# Loss: 6.283856
# Running optimization step 45.
# Loss: 6.258200
# Running optimization step 46.
# Loss: 6.228119
# Running optimization step 47.
# Loss: 6.201334
# Running optimization step 48.
# Loss: 6.158509
# Running optimization step 49.
# Loss: 6.106571
# Running optimization step 50.
# Loss: 6.067358
# Running optimization step 51.
# Loss: 6.036331
# Running optimization step 52.
# Loss: 6.009929
# Running optimization step 53.
# Loss: 5.980657
# Running optimization step 54.
# Loss: 5.932338
# Running optimization step 55.
# Loss: 5.886744
# Running optimization step 56.
# Loss: 5.851251
# Running optimization step 57.
# Loss: 5.827426
# Running optimization step 58.
# Loss: 5.803861
# Running optimization step 59.
# Loss: 5.771662
# Running optimization step 60.
# Loss: 5.741912
# Running optimization step 61.
# Loss: 5.708911
# Running optimization step 62.
# Loss: 5.678748
# Running optimization step 63.
# Loss: 5.654973
# Running optimization step 64.
# Loss: 5.616652
# Running optimization step 65.
# Loss: 5.587470
# Running optimization step 66.
# Loss: 5.556170
# Running optimization step 67.
# Loss: 5.534417
# Running optimization step 68.
# Loss: 5.506903
# Running optimization step 69.
# Loss: 5.479977
# Running optimization step 70.
# Loss: 5.459977
# Running optimization step 71.
# Loss: 5.436239
# Running optimization step 72.
# Loss: 5.404478
# Running optimization step 73.
# Loss: 5.378717
# Running optimization step 74.
# Loss: 5.349386
# Running optimization step 75.
# Loss: 5.331107
# Running optimization step 76.
# Loss: 5.307363
# Running optimization step 77.
# Loss: 5.283884
# Running optimization step 78.
# Loss: 5.263999
# Running optimization step 79.
# Loss: 5.227378
# Running optimization step 80.
# Loss: 5.214334
# Running optimization step 81.
# Loss: 5.177054
# Running optimization step 82.
# Loss: 5.165478
# Running optimization step 83.
# Loss: 5.124094
# Running optimization step 84.
# Loss: 5.105063
# Running optimization step 85.
# Loss: 5.068825
# Running optimization step 86.
# Loss: 5.053032
# Running optimization step 87.
# Loss: 5.019258
# Running optimization step 88.
# Loss: 5.003604
# Running optimization step 89.
# Loss: 4.976569
# Running optimization step 90.
# Loss: 4.959404
# Running optimization step 91.
# Loss: 4.932651
# Running optimization step 92.
# Loss: 4.904899
# Running optimization step 93.
# Loss: 4.879689
# Running optimization step 94.
# Loss: 4.856701
# Running optimization step 95.
# Loss: 4.836130
# Running optimization step 96.
# Loss: 4.817386
# Running optimization step 97.
# Loss: 4.795951
# Running optimization step 98.
# Loss: 4.783698
# Running optimization step 99.
# Loss: 4.761164
# Running optimization step 100.
# Loss: 4.743174
# Running optimization step 101.
# Loss: 4.715681
# Running optimization step 102.
# Loss: 4.692154
# Running optimization step 103.
# Loss: 4.665963
# Running optimization step 104.
# Loss: 4.641022
# Running optimization step 105.
# Loss: 4.611297
# Running optimization step 106.
# Loss: 4.587165
# Running optimization step 107.
# Loss: 4.558914
# Running optimization step 108.
# Loss: 4.529772
# Running optimization step 109.
# Loss: 4.504555
# Running optimization step 110.
# Loss: 4.481377
# Running optimization step 111.
# Loss: 4.454504
# Running optimization step 112.
# Loss: 4.434432
# Running optimization step 113.
# Loss: 4.411790
# Running optimization step 114.
# Loss: 4.389152
# Running optimization step 115.
# Loss: 4.368919
# Running optimization step 116.
# Loss: 4.349631
# Running optimization step 117.
# Loss: 4.329069
# Running optimization step 118.
# Loss: 4.310228
# Running optimization step 119.
# Loss: 4.288082
# Running optimization step 120.
# Loss: 4.269429
# Running optimization step 121.
# Loss: 4.244798
# Running optimization step 122.
# Loss: 4.223905
# Running optimization step 123.
# Loss: 4.206237
# Running optimization step 124.
# Loss: 4.187096
# Running optimization step 125.
# Loss: 4.176167
# Running optimization step 126.
# Loss: 4.162673
# Running optimization step 127.
# Loss: 4.145377
# Running optimization step 128.
# Loss: 4.129818
# Running optimization step 129.
# Loss: 4.129157
# Running optimization step 130.
# Loss: 4.122951
# Running optimization step 131.
# Loss: 4.177616
# Running optimization step 132.
# Loss: 4.104695
# Running optimization step 133.
# Loss: 4.049049
# Running optimization step 134.
# Loss: 4.032665
# Running optimization step 135.
# Loss: 4.022701
# Running optimization step 136.
# Loss: 3.986555
# Running optimization step 137.
# Loss: 3.970522
# Running optimization step 138.
# Loss: 3.938784
# Running optimization step 139.
# Loss: 3.909408
# Running optimization step 140.
# Loss: 3.877205
# Running optimization step 141.
# Loss: 3.847043
# Running optimization step 142.
# Loss: 3.824263
# Running optimization step 143.
# Loss: 3.789755
# Running optimization step 144.
# Loss: 3.756137
# Running optimization step 145.
# Loss: 3.724257
# Running optimization step 146.
# Loss: 3.721240
# Running optimization step 147.
# Loss: 3.697968
# Running optimization step 148.
# Loss: 3.693623
# Running optimization step 149.
# Loss: 3.673152
# Running optimization step 150.
# Loss: 3.646943
# Running optimization step 151.
# Loss: 3.623034
# Running optimization step 152.
# Loss: 3.611956
# Running optimization step 153.
# Loss: 3.615599
# Running optimization step 154.
# Loss: 3.596416
# Running optimization step 155.
# Loss: 3.585623
# Running optimization step 156.
# Loss: 3.577196
# Running optimization step 157.
# Loss: 3.609662
# Running optimization step 158.
# Loss: 3.627254
# Running optimization step 159.
# Loss: 3.638844
# Running optimization step 160.
# Loss: 3.515908
# Running optimization step 161.
# Loss: 3.606202
# Running optimization step 162.
# Loss: 3.658913
# Running optimization step 163.
# Loss: 3.541700
# Running optimization step 164.
# Loss: 3.705469
# Running optimization step 165.
# Loss: 3.525283
# Running optimization step 166.
# Loss: 3.553759
# Running optimization step 167.
# Loss: 3.533729
# Running optimization step 168.
# Loss: 3.494208
# Running optimization step 169.
# Loss: 3.495910
# Running optimization step 170.
# Loss: 3.511369
# Running optimization step 171.
# Loss: 3.470444
# Running optimization step 172.
# Loss: 3.530060
# Running optimization step 173.
# Loss: 3.458227
# Running optimization step 174.
# Loss: 3.447810
# Running optimization step 175.
# Loss: 3.489522
# Running optimization step 176.
# Loss: 3.416477
# Running optimization step 177.
# Loss: 3.433131
# Running optimization step 178.
# Loss: 3.513732
# Running optimization step 179.
# Loss: 3.477767
# Running optimization step 180.
# Loss: 3.454940
# Running optimization step 181.
# Loss: 3.586130
# Running optimization step 182.
# Loss: 3.462403
# Running optimization step 183.
# Loss: 3.481958
# Running optimization step 184.
# Loss: 3.428550
# Running optimization step 185.
# Loss: 3.379646
# Running optimization step 186.
# Loss: 3.393334
# Running optimization step 187.
# Loss: 3.374468
# Running optimization step 188.
# Loss: 3.368846
# Running optimization step 189.
# Loss: 3.343116
# Running optimization step 190.
# Loss: 3.360254
# Running optimization step 191.
# Loss: 3.374942
# Running optimization step 192.
# Loss: 3.386700
# Running optimization step 193.
# Loss: 3.399220
# Running optimization step 194.
# Loss: 3.383647
# Running optimization step 195.
# Loss: 3.350332
# Running optimization step 196.
# Loss: 3.356371
# Running optimization step 197.
# Loss: 3.473650
# Running optimization step 198.
# Loss: 3.326120
# Running optimization step 199.
# Loss: 3.310447
# Running optimization step 200.
# Loss: 3.368027
# Running optimization step 201.
# Loss: 3.322508
# Running optimization step 202.
# Loss: 3.305337
# Running optimization step 203.
# Loss: 3.315742
# Running optimization step 204.
# Loss: 3.360146
# Running optimization step 205.
# Loss: 3.279595
# Running optimization step 206.
# Loss: 3.355161
# Running optimization step 207.
# Loss: 3.305302
# Running optimization step 208.
# Loss: 3.247166
# Running optimization step 209.
# Loss: 3.272791
# Running optimization step 210.
# Loss: 3.324106
# Running optimization step 211.
# Loss: 3.248420
# Running optimization step 212.
# Loss: 3.234825
# Running optimization step 213.
# Loss: 3.225245
# Running optimization step 214.
# Loss: 3.202401
# Running optimization step 215.
# Loss: 3.200168
# Running optimization step 216.
# Loss: 3.205142
# Running optimization step 217.
# Loss: 3.260837
# Running optimization step 218.
# Loss: 3.193411
# Running optimization step 219.
# Loss: 3.208155
# Running optimization step 220.
# Loss: 3.193787
# Running optimization step 221.
# Loss: 3.218059
# Running optimization step 222.
# Loss: 3.322972
# Running optimization step 223.
# Loss: 3.210475
# Running optimization step 224.
# Loss: 3.153518
# Running optimization step 225.
# Loss: 3.205270
# Running optimization step 226.
# Loss: 3.169522
# Running optimization step 227.
# Loss: 3.147659
# Running optimization step 228.
# Loss: 3.135114
# Running optimization step 229.
# Loss: 3.136517
# Running optimization step 230.
# Loss: 3.184754
# Running optimization step 231.
# Loss: 3.261355
# Running optimization step 232.
# Loss: 3.178041
# Running optimization step 233.
# Loss: 3.166310
# Running optimization step 234.
# Loss: 3.450285
# Running optimization step 235.
# Loss: 3.392927
# Running optimization step 236.
# Loss: 3.173667
# Running optimization step 237.
# Loss: 3.315485
# Running optimization step 238.
# Loss: 3.210294
# Running optimization step 239.
# Loss: 3.337839
# Running optimization step 240.
# Loss: 3.441826
# Running optimization step 241.
# Loss: 3.614793
# Running optimization step 242.
# Loss: 3.236845
# Running optimization step 243.
# Loss: 3.323950
# Running optimization step 244.
# Loss: 3.466813
# Running optimization step 245.
# Loss: 3.183774
# Running optimization step 246.
# Loss: 3.442989
# Running optimization step 247.
# Loss: 3.885380
# Running optimization step 248.
# Loss: 3.393873
# Running optimization step 249.
# Loss: 3.534271
# Running optimization step 250.
# Loss: 3.332486
# Running optimization step 251.
# Loss: 3.737592
# Running optimization step 252.
# Loss: 3.586892
# Running optimization step 253.
# Loss: 3.490404
# Running optimization step 254.
# Loss: 3.624166
# Running optimization step 255.
# Loss: 3.441400
# Running optimization step 256.
# Loss: 3.548892
# Running optimization step 257.
# Loss: 3.403908
# Running optimization step 258.
# Loss: 3.484544
# Running optimization step 259.
# Loss: 3.359702
# Running optimization step 260.
# Loss: 3.371103
# Running optimization step 261.
# Loss: 3.316423
# Running optimization step 262.
# Loss: 3.296347
# Running optimization step 263.
# Loss: 3.271549
# Running optimization step 264.
# Loss: 3.295996
# Running optimization step 265.
# Loss: 3.235485
# Running optimization step 266.
# Loss: 3.219992
# Running optimization step 267.
# Loss: 3.216268
# Running optimization step 268.
# Loss: 3.175720
# Running optimization step 269.
# Loss: 3.162044
# Running optimization step 270.
# Loss: 3.156955
# Running optimization step 271.
# Loss: 3.120435
# Running optimization step 272.
# Loss: 3.152225
# Running optimization step 273.
# Loss: 3.127526
# Running optimization step 274.
# Loss: 3.166378
# Running optimization step 275.
# Loss: 3.118105
# Running optimization step 276.
# Loss: 3.163709
# Running optimization step 277.
# Loss: 3.108201
# Running optimization step 278.
# Loss: 3.089797
# Running optimization step 279.
# Loss: 3.122226
# Running optimization step 280.
# Loss: 3.091549
# Running optimization step 281.
# Loss: 3.074319
# Running optimization step 282.
# Loss: 3.099595
# Running optimization step 283.
# Loss: 3.043360
# Running optimization step 284.
# Loss: 3.049594
# Running optimization step 285.
# Loss: 3.074070
# Running optimization step 286.
# Loss: 3.104847
# Running optimization step 287.
# Loss: 3.082510
# Running optimization step 288.
# Loss: 3.048270
# Running optimization step 289.
# Loss: 3.118514
# Running optimization step 290.
# Loss: 3.084404
# Running optimization step 291.
# Loss: 3.097560
# Running optimization step 292.
# Loss: 3.102911
# Running optimization step 293.
# Loss: 3.050420
# Running optimization step 294.
# Loss: 3.110588
# Running optimization step 295.
# Loss: 3.145112
# Running optimization step 296.
# Loss: 3.158012
# Running optimization step 297.
# Loss: 3.110640
# Running optimization step 298.
# Loss: 3.073913
# Running optimization step 299.
# Loss: 3.137293

# %%
#See what this thing did

pylab.imshow(np.concatenate(session.run(fluid.density).data[...,0], axis=1), origin='lower', cmap='magma')

# %%
#Checkout the optimized velocity field

optimized_velocity_field = session.run(states[0].velocity).at_centers()

# %%
pylab.title('Initial y-velocity (optimized)')
pylab.imshow(np.concatenate(optimized_velocity_field.data[...,0], axis=1), origin='lower')

# %%
pylab.title('Initial x-velocity (optimized)')
pylab.imshow(np.concatenate(optimized_velocity_field.data[...,1], axis=1), origin='lower')

# %%
for i in range(len(states)):
    save_name = "vis/blob_frame%d.png"
    pylab.imshow(np.concatenate(session.run(states[i].density).data[...,0], axis=1), origin='lower', cmap='magma')
    pylab.savefig(save_name % (i), bbox_inches='tight')

# %%
print(states[1].density.data[...,0])
# Out:
# Tensor("strided_slice_262:0", shape=(2, 32, 32), dtype=float32)
